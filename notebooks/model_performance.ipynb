# %% [markdown]
# # Here we test our finetuned model's perfomance agianst 300 images
#
# Author: Aidan Murray
#
# Date: 2025-09-26

# %%
# !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl triton cut_cross_entropy unsloth_zoo
# !pip install sentencepiece protobuf "datasets>=3.4.1" huggingface_hub hf_transfer
# !pip install --no-deps unsloth
# Out:
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (0.47.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.10.1)
# Requirement already satisfied: xformers==0.0.29.post3 in /usr/local/lib/python3.12/dist-packages (0.0.29.post3)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.17.1)
# Requirement already satisfied: trl in /usr/local/lib/python3.12/dist-packages (0.22.2)
# Requirement already satisfied: triton in /usr/local/lib/python3.12/dist-packages (3.4.0)
# Requirement already satisfied: cut_cross_entropy in /usr/local/lib/python3.12/dist-packages (25.1.1)
# Requirement already satisfied: unsloth_zoo in /usr/local/lib/python3.12/dist-packages (2025.9.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (5.29.5)
# Requirement already satisfied: datasets>=3.4.1 in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.34.4)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.12/dist-packages (0.1.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.1) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.1) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.1) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.1) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.1) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.1) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.1) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.1) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.1) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1) (2025.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.1) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.1) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.1.9)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1) (3.12.15)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.4.1) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.4.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.4.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.4.1) (2025.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.4.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.4.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.4.1) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=3.4.1) (1.17.0)
# Requirement already satisfied: unsloth in /usr/local/lib/python3.12/dist-packages (2025.9.2)

# %% [markdown]
# ### First, mount the google drive and load the dataset

# %%
from pathlib import Path
from google.colab import drive
import pandas as pd
from PIL import Image
import ast

drive.mount('/content/drive')

BASE_PATH = Path('/content/drive/MyDrive/llm_finetuning')
VAL_PATH = BASE_PATH / "data" / "validation.csv"       # "test.csv" for test dataset
IMAGE_FOLDER = BASE_PATH /  "all_images"

PROMPT = "Analyse the entire image carefully and decide which of the label names correspond to features that are clearly visible in the image."

N = 300      # N = 1000 for test dataset
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def prepare_dataset(n, data_path, im_path, prompt):
  "prepare the dataset for inference by the model"

  df = pd.read_csv(data_path)
  df_indexed = df.set_index('point.media.id')
  media = df_indexed.index.to_series().sample(n=n+100, random_state=42)

  dataset = []
  i = 0
  for i, id in enumerate(media):
    if i >= n:
      break

    lat = df_indexed.loc[id, 'point.pose.lat']
    lon = df_indexed.loc[id, 'point.pose.lon']
    dep = df_indexed.loc[id, 'point.pose.dep']
    realm = df_indexed.loc[id, 'REALM']
    province = df_indexed.loc[id, 'PROVINCE']
    ecoregion = df_indexed.loc[id, 'ECOREGION']

    prompt_context = ""
    # prompt_context = f"\n### Context ###\n(latitude, longitude): ({lat},{lon})\ndepth: {dep}"
    # prompt_context = f"\n### Context ###\nRealm: {realm}\nProvince: {province}\nEcoregion: {ecoregion}"
    # prompt_context = f"\n### Context ###\nEcoregion: {ecoregion}"

    new_prompt = PROMPT + prompt_context

    path = im_path / f"{id}.jpg"
    if not path.exists():
      print("Image not found, skipping ...")
      continue
    i += 1
    print(f"Getting image {i} ...")
    img = Image.open(path)

    mydict = {"id": id,
              "labels": df_indexed.loc[id, 'label.name'],
              "image": img,
              "prompt": new_prompt}
    dataset.append(mydict)

  return dataset

# %%
dataset = prepare_dataset(300, VAL_PATH, IMAGE_FOLDER, PROMPT)
# Out:
# Getting image 1 ...
# Getting image 2 ...
# Getting image 3 ...
# Getting image 4 ...
# Getting image 5 ...
# Getting image 6 ...
# Getting image 7 ...
# Getting image 8 ...
# Getting image 9 ...
# Getting image 10 ...
# Getting image 11 ...
# Getting image 12 ...
# Getting image 13 ...
from unsloth import FastLanguageModel

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "username/model-name", # YOUR MODEL YOU USED FOR TRAINING
    max_seq_length = 4096,
    # dtype = dtype,
    load_in_4bit = True,
)
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# WARNING:xformers:WARNING[XFORMERS]: xFormers can't load C++/CUDA extensions. xFormers was built for:
#     PyTorch 2.6.0+cu124 with CUDA 1204 (you have 2.8.0+cu126)
#     Python  3.12.9 (you have 3.12.11)
#   Please reinstall xformers (see https://github.com/facebookresearch/xformers#installing-xformers)
#   Memory-efficient attention, SwiGLU, sparse and more won't be available.
#   Set XFORMERS_MORE_DETAILS=1 for more details
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.9.2: Fast Qwen2_5_Vl patching. Transformers: 4.56.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.69G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/211 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/791 [00:00<?, ?B/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# video_preprocessor_config.json:   0%|          | 0.00/935 [00:00<?, ?B/s]
# Qwen2_5_VLForConditionalGeneration(
#   (model): Qwen2_5_VLModel(
#     (visual): Qwen2_5_VisionTransformerPretrainedModel(
#       (patch_embed): Qwen2_5_VisionPatchEmbed(
#         (proj): Conv3d(3, 1280, kernel_size=(2, 14, 14), stride=(2, 14, 14), bias=False)
#       )
#       (rotary_pos_emb): Qwen2_5_VisionRotaryEmbedding()
#       (blocks): ModuleList(
#         (0-31): 32 x Qwen2_5_VLVisionBlock(
#           (norm1): Qwen2RMSNorm((1280,), eps=1e-06)
#           (norm2): Qwen2RMSNorm((1280,), eps=1e-06)
#           (attn): Qwen2_5_VLVisionAttention(
#             (qkv): Linear4bit(in_features=1280, out_features=3840, bias=True)
#             (proj): Linear4bit(in_features=1280, out_features=1280, bias=True)
#           )
#           (mlp): Qwen2_5_VLMLP(
#             (gate_proj): Linear4bit(in_features=1280, out_features=3420, bias=True)
#             (up_proj): Linear4bit(in_features=1280, out_features=3420, bias=True)
#             (down_proj): Linear4bit(in_features=3420, out_features=1280, bias=True)
#             (act_fn): SiLU()
#           )
#         )
#       )
#       (merger): Qwen2_5_VLPatchMerger(
#         (ln_q): Qwen2RMSNorm((1280,), eps=1e-06)
#         (mlp): Sequential(
#           (0): Linear(in_features=5120, out_features=5120, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=5120, out_features=3584, bias=True)
#         )
#       )
#     )
#     (language_model): Qwen2_5_VLTextModel(
#       (embed_tokens): Embedding(152064, 3584)
#       (layers): ModuleList(
#         (0-27): 28 x Qwen2_5_VLDecoderLayer(
#           (self_attn): Qwen2_5_VLAttention(
#             (q_proj): Linear4bit(in_features=3584, out_features=3584, bias=True)
#             (k_proj): Linear4bit(in_features=3584, out_features=512, bias=True)
#             (v_proj): Linear4bit(in_features=3584, out_features=512, bias=True)
#             (o_proj): Linear4bit(in_features=3584, out_features=3584, bias=False)
#             (rotary_emb): Qwen2_5_VLRotaryEmbedding()
#           )
#           (mlp): Qwen2MLP(
#             (gate_proj): Linear4bit(in_features=3584, out_features=18944, bias=False)
#             (up_proj): Linear4bit(in_features=3584, out_features=18944, bias=False)
#             (down_proj): Linear4bit(in_features=18944, out_features=3584, bias=False)
#             (act_fn): SiLU()
#           )
#           (input_layernorm): Qwen2RMSNorm((3584,), eps=1e-06)
#           (post_attention_layernorm): Qwen2RMSNorm((3584,), eps=1e-06)
#         )
#       )
#       (norm): Qwen2RMSNorm((3584,), eps=1e-06)
#       (rotary_emb): Qwen2_5_VLRotaryEmbedding()
#     )
#   )
#   (lm_head): Linear(in_features=3584, out_features=152064, bias=False)
# )

# %% [markdown]
# ## Make an inference for each image

# %%
import time
import warnings

ids = []
true_labels = []
predicted_labels = []
raw_predicted_labels = []
failed_parse = 0

start_time = time.time()
for i, element in enumerate(dataset):
  print(f"Generating prompt for image {i}...")
  ids.append(element['id'])

  img = element['image']
  messages = [
      {"role": "user", "content": [
          {"type": "image"},
          {"type": "text", "text": element["prompt"]}
      ]},
  ]

  input_text = tokenizer.apply_chat_template(messages, add_generation_prompt = True)
  inputs = tokenizer(
      img,
      input_text,
      add_special_tokens = False,
      return_tensors = "pt",
  ).to("cuda")

  output_tokens = model.generate(**inputs, max_new_tokens=1028)
  input_length = inputs["input_ids"].shape[1]
  generated_tokens = output_tokens[0][input_length:]
  output_text = tokenizer.decode(generated_tokens, skip_special_tokens=True)
  raw_predicted_labels.append(output_text)

  try:
    y_pred = ast.literal_eval(output_text)
  except (ValueError, SyntaxError) as e:
    warnings.warn(f"Warning: Failed to parse model output from image {element['id']}. Error: {e}")
    y_pred = ['Failed']
    failed_parse += 1
  predicted_labels.append(y_pred)

  y_true = ast.literal_eval(element['labels'])
  true_labels.append(y_true)

end_time = time.time()
# Out:
# Generating prompt for image 0...
# Generating prompt for image 1...
# Generating prompt for image 2...
# Generating prompt for image 3...
# Generating prompt for image 4...
# Generating prompt for image 5...
# Generating prompt for image 6...
# Generating prompt for image 7...
# Generating prompt for image 8...
# Generating prompt for image 9...
# Generating prompt for image 10...
# Generating prompt for image 11...
# Generating prompt for image 12...
# Generating prompt for image 13...
# Generating prompt for image 14...
# Generating prompt for image 15...
# Generating prompt for image 16...
# Generating prompt for image 17...
# Generating prompt for image 18...
# Generating prompt for image 19...
# Generating prompt for image 20...
# Generating prompt for image 21...
# Generating prompt for image 22...
# Generating prompt for image 23...
# Generating prompt for image 24...
# Generating prompt for image 25...
# Generating prompt for image 26...
# Generating prompt for image 27...
# Generating prompt for image 28...
# Generating prompt for image 29...
# Generating prompt for image 30...
# Generating prompt for image 31...
# Generating prompt for image 32...
# Generating prompt for image 33...
# Generating prompt for image 34...
# Generating prompt for image 35...
# Generating prompt for image 36...
# Generating prompt for image 37...
# Generating prompt for image 38...
# Generating prompt for image 39...
# Generating prompt for image 40...
# Generating prompt for image 41...
# Generating prompt for image 42...
# Generating prompt for image 43...
# Generating prompt for image 44...
# Generating prompt for image 45...
# Generating prompt for image 46...
# Generating prompt for image 47...
# Generating prompt for image 48...
# Generating prompt for image 49...
# Generating prompt for image 50...
# Generating prompt for image 51...
# Generating prompt for image 52...
# Generating prompt for image 53...
# Generating prompt for image 54...
# Generating prompt for image 55...
# Generating prompt for image 56...
# Generating prompt for image 57...
# Generating prompt for image 58...
# Generating prompt for image 59...
# Generating prompt for image 60...
# Generating prompt for image 61...
# Generating prompt for image 62...
# Generating prompt for image 63...
# Generating prompt for image 64...
# Generating prompt for image 65...
# Generating prompt for image 66...
# Generating prompt for image 67...
# Generating prompt for image 68...
# Generating prompt for image 69...
# Generating prompt for image 70...
# Generating prompt for image 71...
# Generating prompt for image 72...
# Generating prompt for image 73...
# Generating prompt for image 74...
# Generating prompt for image 75...
# Generating prompt for image 76...
# Generating prompt for image 77...
# Generating prompt for image 78...
# Generating prompt for image 79...
# Generating prompt for image 80...
# Generating prompt for image 81...
# Generating prompt for image 82...
# Generating prompt for image 83...
# Generating prompt for image 84...
# Generating prompt for image 85...
# Generating prompt for image 86...
# Generating prompt for image 87...
# Generating prompt for image 88...
# Generating prompt for image 89...
# Generating prompt for image 90...
# Generating prompt for image 91...
# Generating prompt for image 92...
# Generating prompt for image 93...
# Generating prompt for image 94...
# Generating prompt for image 95...
# Generating prompt for image 96...
# Generating prompt for image 97...
# Generating prompt for image 98...
# Generating prompt for image 99...
# Generating prompt for image 100...
# Generating prompt for image 101...
# Generating prompt for image 102...
# Generating prompt for image 103...
# Generating prompt for image 104...
# Generating prompt for image 105...
# Generating prompt for image 106...
# Generating prompt for image 107...
# Generating prompt for image 108...
# Generating prompt for image 109...
# Generating prompt for image 110...
# Generating prompt for image 111...
# Generating prompt for image 112...
# Generating prompt for image 113...
# Generating prompt for image 114...
# Generating prompt for image 115...
# Generating prompt for image 116...
# Generating prompt for image 117...
# Generating prompt for image 118...
# Generating prompt for image 119...
# Generating prompt for image 120...
# Generating prompt for image 121...
# Generating prompt for image 122...
# Generating prompt for image 123...
# Generating prompt for image 124...
# Generating prompt for image 125...
# Generating prompt for image 126...
# Generating prompt for image 127...
# Generating prompt for image 128...
# Generating prompt for image 129...
# Generating prompt for image 130...
# Generating prompt for image 131...
# Generating prompt for image 132...
# Generating prompt for image 133...
# Generating prompt for image 134...
# Generating prompt for image 135...
# Generating prompt for image 136...
# Generating prompt for image 137...
# Generating prompt for image 138...
# Generating prompt for image 139...
# Generating prompt for image 140...
# Generating prompt for image 141...
# Generating prompt for image 142...
# Generating prompt for image 143...
# Generating prompt for image 144...
# Generating prompt for image 145...
# Generating prompt for image 146...
# Generating prompt for image 147...
# Generating prompt for image 148...
# Generating prompt for image 149...
# Generating prompt for image 150...
# Generating prompt for image 151...
# Generating prompt for image 152...
# Generating prompt for image 153...
# Generating prompt for image 154...
# Generating prompt for image 155...
# Generating prompt for image 156...
# Generating prompt for image 157...
# Generating prompt for image 158...
# Generating prompt for image 159...
# Generating prompt for image 160...
# Generating prompt for image 161...
# Generating prompt for image 162...
# Generating prompt for image 163...
# Generating prompt for image 164...
# Generating prompt for image 165...
# Generating prompt for image 166...
# Generating prompt for image 167...
# Generating prompt for image 168...
# Generating prompt for image 169...
# Generating prompt for image 170...
# Generating prompt for image 171...
# Generating prompt for image 172...
# Generating prompt for image 173...
# Generating prompt for image 174...
# Generating prompt for image 175...
# Generating prompt for image 176...
# Generating prompt for image 177...
# Generating prompt for image 178...
# Generating prompt for image 179...
# Generating prompt for image 180...
# Generating prompt for image 181...
# Generating prompt for image 182...
# Generating prompt for image 183...
# Generating prompt for image 184...
# Generating prompt for image 185...
# Generating prompt for image 186...
# Generating prompt for image 187...
# Generating prompt for image 188...
# Generating prompt for image 189...
# Generating prompt for image 190...
# Generating prompt for image 191...
# Generating prompt for image 192...
# Generating prompt for image 193...
# Generating prompt for image 194...
# Generating prompt for image 195...
# Generating prompt for image 196...
# Generating prompt for image 197...
# Generating prompt for image 198...
# Generating prompt for image 199...
# Generating prompt for image 200...
# Generating prompt for image 201...
# Generating prompt for image 202...
# Generating prompt for image 203...
# Generating prompt for image 204...
# Generating prompt for image 205...
# Generating prompt for image 206...
# Generating prompt for image 207...
# Generating prompt for image 208...
# Generating prompt for image 209...
# Generating prompt for image 210...
# Generating prompt for image 211...
# Generating prompt for image 212...
# Generating prompt for image 213...
# Generating prompt for image 214...
# Generating prompt for image 215...
# Generating prompt for image 216...
# Generating prompt for image 217...
# Generating prompt for image 218...
# Generating prompt for image 219...
# Generating prompt for image 220...
# Generating prompt for image 221...
# Generating prompt for image 222...
# Generating prompt for image 223...
# Generating prompt for image 224...
# Generating prompt for image 225...
# Generating prompt for image 226...
# Generating prompt for image 227...
# Generating prompt for image 228...
# Generating prompt for image 229...
# Generating prompt for image 230...
# Generating prompt for image 231...
# Generating prompt for image 232...
# Generating prompt for image 233...
# Generating prompt for image 234...
# Generating prompt for image 235...
# Generating prompt for image 236...
# Generating prompt for image 237...
# Generating prompt for image 238...
# Generating prompt for image 239...
# Generating prompt for image 240...
# Generating prompt for image 241...
# Generating prompt for image 242...
# Generating prompt for image 243...
# Generating prompt for image 244...
# Generating prompt for image 245...
# Generating prompt for image 246...
# Generating prompt for image 247...
# Generating prompt for image 248...
# Generating prompt for image 249...
# Generating prompt for image 250...
# Generating prompt for image 251...
# Generating prompt for image 252...
# Generating prompt for image 253...
# Generating prompt for image 254...
# Generating prompt for image 255...
# Generating prompt for image 256...
# Generating prompt for image 257...
# Generating prompt for image 258...
# Generating prompt for image 259...
# Generating prompt for image 260...
# Generating prompt for image 261...
# Generating prompt for image 262...
# Generating prompt for image 263...
# Generating prompt for image 264...
# Generating prompt for image 265...
# Generating prompt for image 266...
# Generating prompt for image 267...
# Generating prompt for image 268...
# Generating prompt for image 269...
# Generating prompt for image 270...
# Generating prompt for image 271...
# Generating prompt for image 272...
# Generating prompt for image 273...
# Generating prompt for image 274...
# Generating prompt for image 275...
# Generating prompt for image 276...
# Generating prompt for image 277...
# Generating prompt for image 278...
# Generating prompt for image 279...
# Generating prompt for image 280...
# Generating prompt for image 281...
# Generating prompt for image 282...
# Generating prompt for image 283...
# Generating prompt for image 284...
# Generating prompt for image 285...
# Generating prompt for image 286...
# Generating prompt for image 287...
# Generating prompt for image 288...
# Generating prompt for image 289...
# Generating prompt for image 290...
# Generating prompt for image 291...
# Generating prompt for image 292...
# Generating prompt for image 293...
# Generating prompt for image 294...
# Generating prompt for image 295...
# Generating prompt for image 296...
# Generating prompt for image 297...
# Generating prompt for image 298...

# %% [markdown]
# ## Evaluate the accuracy of the model

# %%
def f1_score(seq1, seq2):
  "Converts the inputs to sets and returns the f1 score of these sets"

  set_1 = set(seq1)
  set_2 = set(seq2)
  f1 = (2 * len(set_1.intersection(set_2))) / (len(set_1) + len(set_2))

  return f1

# %%
evals = [f1_score(true_labels[i], predicted_labels[i]) for i in range(len(predicted_labels))]

# %% [markdown]
# ## Write output to files

# %%
OUTPUT_PATH = BASE_PATH / "output_7B_1300_justeco"
OUTPUT_PATH.mkdir(exist_ok=True)

with open(OUTPUT_PATH / "predicted_labels.txt", "w") as f:
  for line in predicted_labels:
    f.write(str(line) + '\n')

with open(OUTPUT_PATH / "raw_predicted_labels.txt", "w") as f:
  for line in raw_predicted_labels:
    f.write(line + '\n')

df_eval = pd.DataFrame()
df_eval["ID"] = ids
df_eval["F1 Score"] = evals
df_eval.to_csv(OUTPUT_PATH / "evals.csv")
df_eval["F1 Score"].describe().to_csv(OUTPUT_PATH / "eval_stats.csv")

with open(OUTPUT_PATH / "info.txt", "w") as f:
  f.write(f"Number of failed parses: {failed_parse}\n")
  f.write(f"Execution time: {end_time - start_time}")

print("done")
# Out:
# done
